# %% [markdown]
# # Getting plots for the CBO algorithm

# %%
import os
# set the directory to the root
os.chdir("/Users/jeandurand/Documents/Masters Thesis/causal_bayes_opt")
from algorithms.CBO_algorithm import CBO

model = CBO("Toy")
model.run_algorithm(T=3)
# Out:
# warning in stationary: failed to import cython module: falling back to numpy
# warning in coregionalize: failed to import cython module: falling back to numpy
# warning in choleskies: failed to import cython module: falling back to numpy
# INFO:root:Setting up the toy graph
# INFO:root:Initializing the Toy Graph Structures
# INFO:root:Getting the variables (mis and pomis) for the CBO algorithm
# INFO:root:Fitting the Gaussian Processes based on the new data
# INFO:GP:initializing Y
# INFO:GP:initializing inference method
# INFO:GP:adding kernel and likelihood as parameters
# INFO:GP:initializing Y
# INFO:GP:initializing inference method
# INFO:GP:adding kernel and likelihood as parameters
# INFO:root:Using the fixed equal cost structure
# INFO:root:------ Iteration 0: Observed 1, where epsilon = 4.3119475887790335 ------
# INFO:root:------ Iteration 1: Intervened 1 where epsilon = 4.269255038395083  ------
# INFO:root:Using the Causal Gaussian Prior
# INFO:GP:initializing Y
# INFO:GP:initializing inference method
# INFO:GP:adding kernel and likelihood as parameters
# INFO:root:Using the Causal Gaussian Prior
# INFO:GP:initializing Y
# INFO:GP:initializing inference method
# INFO:GP:adding kernel and likelihood as parameters
# Optimization restart 1/5, f = -1.2733030266742276
# Optimization restart 2/5, f = -1.2733030637342708
# Optimization restart 3/5, f = -1.2733030637208707
# Optimization restart 4/5, f = -1.2733030638358906
# Optimization restart 5/5, f = -1.2733030638355645
# Optimization restart 1/5, f = -0.12995099136480404
# Optimization restart 2/5, f = -0.05109198562268413
# Optimization restart 3/5, f = -0.07389177640562417
# Optimization restart 4/5, f = -0.2611780981845091
# Optimization restart 5/5, f = 0.10949484854585312
# INFO:root:Starting gradient-based optimization of acquisition function <class 'emukit.core.acquisition.acquisition.Quotient'>
# INFO:root:Starting gradient-based optimization of acquisition function <class 'emukit.core.acquisition.acquisition.Quotient'>
# INFO:root:Selected intervention ('Z',) at [[-4.806295]] with y = [[-1.17788127]]
# INFO:root:Current global optimum -1.1778812727794183
# INFO:root:------ Iteration 2: Intervened 2 where epsilon = 4.269255038395083  ------
# INFO:root:Using the Causal Gaussian Prior
# INFO:GP:initializing Y
# INFO:GP:initializing inference method
# INFO:GP:adding kernel and likelihood as parameters
# Optimization restart 1/5, f = 1.6919382090164405
# Optimization restart 2/5, f = 1.6919535796936929
# Optimization restart 3/5, f = 1.6919379939526162
# Optimization restart 4/5, f = 1.691991757157459
# Optimization restart 5/5, f = 1.6919635901698398
# INFO:root:Starting gradient-based optimization of acquisition function <class 'emukit.core.acquisition.acquisition.Quotient'>
# INFO:root:Starting gradient-based optimization of acquisition function <class 'emukit.core.acquisition.acquisition.Quotient'>
# INFO:root:Selected intervention ('Z',) at [[2.94584096]] with y = [[-1.84394363]]
# INFO:root:Current global optimum -1.843943629580587
