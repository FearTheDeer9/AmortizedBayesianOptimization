# %% [markdown]
# # Experiments with the synthetic graph

# %%
import os
# set the directory to the root
os.chdir("/Users/jeandurand/Documents/Masters Thesis/causal_bayes_opt")

from utils.graph_utils.synthetics_graph import SyntheticGraph
from utils.graph_utils.toy_graph import ToyGraph
from utils.graph_utils.graph_functions import get_all_intervention_sets
from utils.sem_sampling import sample_model
from algorithms.BO_algorithm import BO
from algorithms.CBO_algorithm import CBO
graph = SyntheticGraph()
model = graph.SEM()
samples = sample_model(model)
# Out:
# INFO:root:Setting up the structural equation model for the Synthetic Graph

# %%
graph.show_graphical_model()

# %%
graph.refit_models(samples)
graph.get_all_do()
# Out:
# INFO:GP:initializing Y
# INFO:GP:initializing inference method
# INFO:GP:adding kernel and likelihood as parameters
# INFO:GP:initializing Y
# INFO:GP:initializing inference method
# INFO:GP:adding kernel and likelihood as parameters
# INFO:GP:initializing Y
# INFO:GP:initializing inference method
# INFO:GP:adding kernel and likelihood as parameters
# INFO:GP:initializing Y
# INFO:GP:initializing inference method
# INFO:GP:adding kernel and likelihood as parameters
# INFO:GP:initializing Y
# INFO:GP:initializing inference method
# INFO:GP:adding kernel and likelihood as parameters
# INFO:GP:initializing Y
# INFO:GP:initializing inference method
# INFO:GP:adding kernel and likelihood as parameters
# INFO:root:Getting the do-functions for the ToyGraph
# {'compute_do_E': <bound method SyntheticGraph.compute_do_E of <utils.graph_utils.synthetics_graph.SyntheticGraph object at 0x104cd3a90>>,
# ...

# %%
CBO("Synthetic", T=5)
# Out:
# INFO:root:Setting up the synthetic graph
# INFO:root:Setting up the structural equation model for the Synthetic Graph
# INFO:GP:initializing Y
# INFO:GP:initializing inference method
# INFO:GP:adding kernel and likelihood as parameters
# INFO:GP:initializing Y
# INFO:GP:initializing inference method
# INFO:GP:adding kernel and likelihood as parameters
# INFO:GP:initializing Y
# INFO:GP:initializing inference method
# INFO:GP:adding kernel and likelihood as parameters
# INFO:GP:initializing Y
# INFO:GP:initializing inference method
# INFO:GP:adding kernel and likelihood as parameters
# INFO:GP:initializing Y
# INFO:GP:initializing inference method
# INFO:GP:adding kernel and likelihood as parameters
# INFO:GP:initializing Y
# INFO:GP:initializing inference method
# INFO:GP:adding kernel and likelihood as parameters
# INFO:root:Using the fixed equal cost structure
# INFO:root:------ Iteration 0: Observed 1, where epsilon = 0.00021550222766484665 ------
# ...
