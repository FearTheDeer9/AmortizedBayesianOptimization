# %% [markdown]
# # Results for the unknown graph methodology

# %%
# import os
# os.chdir("/Users/jeandurand/Documents/Masters Thesis/causal_bayes_opt")
from result_utils import all_means, box_plots_mean, all_best, all_uncertainties, iterations_to_min, plot_everything

# %% [markdown]
# # The average case

# %%
base_path = "ToyGraphUnknown"
# plot_everything(base_path=base_path, experiment="Best_Y", n_obs=10, num_cbo_graphs=7,save_file=False, plot_ceo=True, graph_idxs = [0, 4, 6])
mean_results = all_means(base_path=base_path, num_cbo_graphs=1, n_obs=200, has_ceo=False, has_cbo=False, has_bo=False)
print(mean_results)
box_plots_mean(mean_results, experiment="Mean")
# Out:
# {'cbo_unknown': {'mean': -1.6736205581693426, 'std': 0.3130890074628877}}

# %%
base_path = "Graph6Unknown"
# plot_everything(base_path=base_path, experiment="Best_Y", n_obs=10, num_cbo_graphs=7,save_file=False, plot_ceo=True, graph_idxs = [0, 4, 6])
mean_results = all_means(base_path=base_path, num_cbo_graphs=1, n_obs=200, has_ceo=False, has_cbo=False, has_bo=False)
print(mean_results)
box_plots_mean(mean_results, experiment="Mean")
# Out:
# {'cbo_unknown': {'mean': 13.459412048364136, 'std': 0.25662865950889896}}

# %% [markdown]
# # The best case

# %%
base_path = "ToyGraphUnknown"
# plot_everything(base_path=base_path, experiment="Best_Y", n_obs=10, num_cbo_graphs=7,save_file=False, plot_ceo=True, graph_idxs = [0, 4, 6])
mean_results = all_best(base_path=base_path, num_cbo_graphs=1, n_obs=200, has_ceo=False, has_cbo=False, has_bo=False)
print(mean_results)
box_plots_mean(mean_results, experiment="Min")
# Out:
# {'cbo_unknown': {'mean': -1.92185554458167, 'std': 0.1755635108978801}}

# %%
base_path = "Graph6Unknown"
# plot_everything(base_path=base_path, experiment="Best_Y", n_obs=10, num_cbo_graphs=7,save_file=False, plot_ceo=True, graph_idxs = [0, 4, 6])
mean_results = all_best(base_path=base_path, num_cbo_graphs=1, n_obs=200, has_ceo=False, has_cbo=False, has_bo=False)
print(mean_results)
box_plots_mean(mean_results, experiment="Min")
# Out:
# {'cbo_unknown': {'mean': 13.234258178190037, 'std': 0.16666829109435544}}
