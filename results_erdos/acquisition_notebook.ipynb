# %% [markdown]
# # Testing the different acquisition functions

# %%
import os
os.chdir("/vol/bitbucket/jd123/causal_bayes_opt/")

from results_erdos.results_utils import plot_acquisitions

# %% [markdown]
# # ToyGraphUnknown

# %%
plot_acquisitions("ToyGraphUnknown", "Best_Y")

# %%
plot_acquisitions("ToyGraphUnknown", "Per_trial_Y")

# %%
plot_acquisitions("ToyGraphUnknown", "Best_Y", use_dr=True)

# %%
plot_acquisitions("ToyGraphUnknown", "Per_trial_Y", use_dr=True)

# %% [markdown]
# # Graph 6 Unknown

# %%
plot_acquisitions("Graph6Unknown", "Best_Y")

# %%
plot_acquisitions("Graph6Unknown", "Per_trial_Y")

# %%
plot_acquisitions("Graph6Unknown", "Best_Y", use_dr=True)

# %%
plot_acquisitions("Graph6Unknown", "Per_trial_Y", use_dr=True)

# %% [markdown]
# # Graph 5 Unknown

# %%
plot_acquisitions("Graph5Unknown", "Best_Y")

# %%
plot_acquisitions("Graph5Unknown", "Per_trial_Y")

# %%
plot_acquisitions("Graph5Unknown", "Best_Y", use_dr=True)

# %%
plot_acquisitions("Graph5Unknown", "Per_trial_Y", use_dr=True)

# %% [markdown]
# # Average the acquisition functions

# %%
import os
from results_utils import plot_acquisitions_all, plot_acquisitions_all_boxplot

os.chdir("/vol/bitbucket/jd123/causal_bayes_opt/")
    
plot_acquisitions_all_boxplot(save_file=True)
