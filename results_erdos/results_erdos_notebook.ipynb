# %% [markdown]
# # ErdosRenyi Graphs

# %%
from results_utils import plot_everything, all_means, all_best
import os
print(os.getcwd())
# Out:
# /vol/bitbucket/jd123/causal_bayes_opt/results_erdos

# %% [markdown]
# # Erdos 10 - Linear

# %%
base_path = "/vol/bitbucket/jd123/causal_bayes_opt/results/Erdos10"
plot_everything(base_path=base_path, experiment="Best_Y", plot_cbo=True, plot_all=False, plot_dr2=True, plot_random=True)
plot_everything(base_path=base_path, experiment="Per_trial_Y", plot_cbo=True, plot_all=False, plot_dr2=True, plot_random=True)

# %%
base_path = "/vol/bitbucket/jd123/causal_bayes_opt/results/Erdos10"
plot_everything(base_path=base_path, experiment="Best_Y",n_obs=300, plot_cbo=True, plot_all=True, plot_dr2=True, plot_random=True)
plot_everything(base_path=base_path, experiment="Per_trial_Y",n_obs=300, plot_cbo=True, plot_all=True, plot_dr2=True, plot_random=True)

# %%
base_path = "/vol/bitbucket/jd123/causal_bayes_opt/results/Erdos10"
plot_everything(base_path=base_path, experiment="Best_Y",n_obs=500, plot_cbo=True, plot_all=True, plot_dr2=True, plot_random=True)
plot_everything(base_path=base_path, experiment="Per_trial_Y",n_obs=500, plot_cbo=True, plot_all=True, plot_dr2=True, plot_random=True)

# %% [markdown]
# # Erdos 10 - Nonlinear

# %%
base_path = "/vol/bitbucket/jd123/causal_bayes_opt/results/Erdos10"
plot_everything(base_path=base_path, experiment="Best_Y", nonlinear=True, plot_cbo=True, plot_all=False, plot_dr2=True, plot_random=True)
plot_everything(base_path=base_path, experiment="Per_trial_Y", nonlinear=True, plot_cbo=True, plot_all=False, plot_dr2=True, plot_random=True)

# %%
base_path = "/vol/bitbucket/jd123/causal_bayes_opt/results/Erdos10"
plot_everything(base_path=base_path, experiment="Best_Y",nonlinear=True, n_obs=300, plot_cbo=True, plot_all=False, plot_dr2=True, plot_random=True)
plot_everything(base_path=base_path, experiment="Per_trial_Y",nonlinear=True, n_obs=300, plot_cbo=True, plot_all=False, plot_dr2=True, plot_random=True)

# %%
base_path = "/vol/bitbucket/jd123/causal_bayes_opt/results/Erdos10"
plot_everything(base_path=base_path, experiment="Best_Y",nonlinear=True, n_obs=500, plot_cbo=True, plot_all=False, plot_dr2=True, plot_random=True)
plot_everything(base_path=base_path, experiment="Per_trial_Y",nonlinear=True, n_obs=500, plot_cbo=True, plot_all=False, plot_dr2=True, plot_random=True)

# %% [markdown]
# # Erdos 15 - Linear

# %%
base_path = "/vol/bitbucket/jd123/causal_bayes_opt/results/Erdos15"
plot_everything(base_path=base_path, experiment="Best_Y", plot_cbo=True, plot_all=False, plot_dr2=True, plot_random=True)
plot_everything(base_path=base_path, experiment="Per_trial_Y", plot_cbo=True, plot_all=False, plot_dr2=True, plot_random=True)

# %%
base_path = "/vol/bitbucket/jd123/causal_bayes_opt/results/Erdos15"
plot_everything(base_path=base_path, experiment="Best_Y", n_obs=300, plot_cbo=True, plot_all=False, plot_dr2=True, plot_random=True)
plot_everything(base_path=base_path, experiment="Per_trial_Y", n_obs=300, plot_cbo=True, plot_all=False, plot_dr2=True, plot_random=True)

# %%
base_path = "/vol/bitbucket/jd123/causal_bayes_opt/results/Erdos15"
plot_everything(base_path=base_path, experiment="Best_Y", n_obs=500, plot_cbo=True, plot_all=False, plot_dr2=True, plot_random=True)
plot_everything(base_path=base_path, experiment="Per_trial_Y", n_obs=500, plot_cbo=True, plot_all=False, plot_dr2=True, plot_random=True)

# %% [markdown]
# ## Erdos 15 - Nonlinear

# %%
base_path = "/vol/bitbucket/jd123/causal_bayes_opt/results/Erdos15"
plot_everything(base_path=base_path, experiment="Best_Y", nonlinear=True, n_obs=200, plot_cbo=True, plot_all=False, plot_dr2=True, plot_random=True)
plot_everything(base_path=base_path, experiment="Per_trial_Y",nonlinear=True, n_obs=200, plot_cbo=True, plot_all=False, plot_dr2=True, plot_random=True)

# %%
base_path = "/vol/bitbucket/jd123/causal_bayes_opt/results/Erdos15"
plot_everything(base_path=base_path, experiment="Best_Y", nonlinear=True, n_obs=300, plot_cbo=True, plot_all=False, plot_dr2=True, plot_random=True)
plot_everything(base_path=base_path, experiment="Per_trial_Y",nonlinear=True, n_obs=300, plot_cbo=True, plot_all=False, plot_dr2=True, plot_random=True)

# %%
base_path = "/vol/bitbucket/jd123/causal_bayes_opt/results/Erdos15"
plot_everything(base_path=base_path, experiment="Best_Y", nonlinear=True, n_obs=500, plot_cbo=True, plot_all=False, plot_dr2=True, plot_random=True)
plot_everything(base_path=base_path, experiment="Per_trial_Y",nonlinear=True, n_obs=500, plot_cbo=True, plot_all=False, plot_dr2=True, plot_random=True)

# %% [markdown]
# # Erdos 20

# %%
base_path = "/vol/bitbucket/jd123/causal_bayes_opt/results/Erdos20"
plot_everything(base_path=base_path, experiment="Best_Y", nonlinear=False, n_obs=200, plot_cbo=True, plot_all=False, plot_dr2=True, plot_random=True)
plot_everything(base_path=base_path, experiment="Per_trial_Y",nonlinear=False, n_obs=200, plot_cbo=True, plot_all=False, plot_dr2=True, plot_random=True)

# %%
base_path = "/vol/bitbucket/jd123/causal_bayes_opt/results/Erdos20"
plot_everything(base_path=base_path, experiment="Best_Y", nonlinear=False, n_obs=300, plot_cbo=True, plot_all=False, plot_dr2=True, plot_random=True)
plot_everything(base_path=base_path, experiment="Per_trial_Y",nonlinear=False, n_obs=300, plot_cbo=True, plot_all=False, plot_dr2=True, plot_random=True)

# %%
base_path = "/vol/bitbucket/jd123/causal_bayes_opt/results/Erdos20"
plot_everything(base_path=base_path, experiment="Best_Y", nonlinear=False, n_obs=500, plot_cbo=True, plot_all=False, plot_dr2=True, plot_random=True)
plot_everything(base_path=base_path, experiment="Per_trial_Y",nonlinear=False, n_obs=500, plot_cbo=True, plot_all=False, plot_dr2=True, plot_random=True)

# %% [markdown]
# # Erdos 20 - Nonlinear

# %%
base_path = "/vol/bitbucket/jd123/causal_bayes_opt/results/Erdos20"
plot_everything(base_path=base_path, experiment="Best_Y", nonlinear=True, n_obs=200, plot_cbo=True, plot_all=False, plot_dr2=True, plot_random=True)
plot_everything(base_path=base_path, experiment="Per_trial_Y",nonlinear=True, n_obs=200, plot_cbo=True, plot_all=False, plot_dr2=True, plot_random=True)

# %%
base_path = "/vol/bitbucket/jd123/causal_bayes_opt/results/Erdos20"
plot_everything(base_path=base_path, experiment="Best_Y", nonlinear=True, n_obs=300, plot_cbo=True, plot_all=False, plot_dr2=True, plot_random=True)
plot_everything(base_path=base_path, experiment="Per_trial_Y",nonlinear=True, n_obs=300, plot_cbo=True, plot_all=False, plot_dr2=True, plot_random=True)

# %%
base_path = "/vol/bitbucket/jd123/causal_bayes_opt/results/Erdos20"
plot_everything(base_path=base_path, experiment="Best_Y", nonlinear=True, n_obs=500, plot_cbo=True, plot_all=False, plot_dr2=True, plot_random=True)
plot_everything(base_path=base_path, experiment="Per_trial_Y",nonlinear=True, n_obs=500, plot_cbo=True, plot_all=False, plot_dr2=True, plot_random=True)

# %% [markdown]
# # Getting overall summary statistics (maybe boxplots)

# %%
from results_utils import plot_everything, all_means, all_best
base_path = "/vol/bitbucket/jd123/causal_bayes_opt/results/Ecoli1"
plot_everything(base_path=base_path, experiment="Best_Y", plot_cbo=True, plot_all=False, plot_dr2=True, plot_random=True, n_int=1)
plot_everything(base_path=base_path, experiment="Per_trial_Y", plot_cbo=True, plot_all=False, plot_dr2=True, plot_random=True, n_int=1)

# %%
from results_utils import plot_everything, all_means, all_best
base_path = "/vol/bitbucket/jd123/causal_bayes_opt/results/Ecoli2"
plot_everything(base_path=base_path, experiment="Best_Y", plot_cbo=True, plot_all=False, plot_dr2=True, plot_random=True, n_int=1)
plot_everything(base_path=base_path, experiment="Per_trial_Y", plot_cbo=True, plot_all=False, plot_dr2=True, plot_random=True, n_int=1)

# %%
import os
os.chdir("/vol/bitbucket/jd123/causal_bayes_opt/results")
from results_utils import summarise_ecoli1_per_iteration
summarise_ecoli1_per_iteration()

# %%
from results_utils import summarise_erdos20_per_iteration
summarise_erdos20_per_iteration()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 2
#       1 from results_utils import summarise_erdos20_per_iteration
# ----> 2 summarise_erdos20_per_iteration()
#
# File /vol/bitbucket/jd123/causal_bayes_opt/results_erdos/results_utils.py:920, in summarise_erdos20_per_iteration()
#     918 def summarise_erdos20_per_iteration():
#     919     # First plot
# --> 920     plot_everything(
#     921         base_path="Erdos20",
#     922         experiment="Best_Y",
#     923         nonlinear=True,
#     924         n_obs=200,
#     925         plot_cbo=True,
#     926         plot_all=False,
#     927         plot_dr2=True,
#     928         plot_random=True,
#     929     )
#     930     fig1 = plt.gcf()
#     931     fig1.canvas.draw()
#
# ...
